# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from datetime import datetime

# %%
# 데이터 로드
data = pd.read_csv("F:/kdt jupyter/Project/Data/continuous_factory_process.csv")
data.head(3)
# Out:
#             time_stamp  AmbientConditions.AmbientHumidity.U.Actual  \
# 0  2019-03-06 10:52:33                                       17.24
# 1  2019-03-06 10:52:34                                       17.24
# 2  2019-03-06 10:52:35                                       17.24
#
#    AmbientConditions.AmbientTemperature.U.Actual  \
# 0                                          23.53
# 1                                          23.53
# 2                                          23.53
#
#    Machine1.RawMaterial.Property1  Machine1.RawMaterial.Property2  \
# 0                           11.54                             200
# 1                           11.54                             200
# 2                           11.54                             200
#
#    Machine1.RawMaterial.Property3  Machine1.RawMaterial.Property4  \
# 0                           963.0                             247
# 1                           963.0                             247
# ...

# %%
data.dtypes
# Out:
# time_stamp                                        object
# AmbientConditions.AmbientHumidity.U.Actual       float64
# AmbientConditions.AmbientTemperature.U.Actual    float64
# Machine1.RawMaterial.Property1                   float64
# Machine1.RawMaterial.Property2                     int64
#                                                   ...
# Stage2.Output.Measurement12.U.Setpoint           float64
# Stage2.Output.Measurement13.U.Actual             float64
# Stage2.Output.Measurement13.U.Setpoint           float64
# Stage2.Output.Measurement14.U.Actual             float64
# Stage2.Output.Measurement14.U.Setpoint           float64
# Length: 116, dtype: object

# %%
# copy 생성
df1 = data.copy()
df1.head(3)
# Out:
#             time_stamp  AmbientConditions.AmbientHumidity.U.Actual  \
# 0  2019-03-06 10:52:33                                       17.24
# 1  2019-03-06 10:52:34                                       17.24
# 2  2019-03-06 10:52:35                                       17.24
#
#    AmbientConditions.AmbientTemperature.U.Actual  \
# 0                                          23.53
# 1                                          23.53
# 2                                          23.53
#
#    Machine1.RawMaterial.Property1  Machine1.RawMaterial.Property2  \
# 0                           11.54                             200
# 1                           11.54                             200
# 2                           11.54                             200
#
#    Machine1.RawMaterial.Property3  Machine1.RawMaterial.Property4  \
# 0                           963.0                             247
# 1                           963.0                             247
# ...

# %%
# time_stamp 데이터 타입 string -> timestamp
df1["time_stamp"] = pd.to_datetime(df1["time_stamp"])

# %% [markdown]
# # Stage1 Input

# %% [markdown]
# ##### Ambient Conditions

# %%
plt.plot(df1["time_stamp"], df1["AmbientConditions.AmbientHumidity.U.Actual"])

# %%
plt.plot(df1["time_stamp"], df1["AmbientConditions.AmbientTemperature.U.Actual"])

# %% [markdown]
# ## Machine 1,2,3 Raw Material Property 1,2,3,4

# %%
fig, ax = plt.subplots(4, 3, figsize = (15, 9))

ax[0, 0].plot(df1["time_stamp"], df1["Machine1.RawMaterial.Property1"], "r")
ax[1, 0].plot(df1["time_stamp"], df1["Machine1.RawMaterial.Property2"], "g")
ax[2, 0].plot(df1["time_stamp"], df1["Machine1.RawMaterial.Property3"], "b")
ax[3, 0].plot(df1["time_stamp"], df1["Machine1.RawMaterial.Property4"], "k")

ax[0, 1].plot(df1["time_stamp"], df1["Machine2.RawMaterial.Property1"], "r")
ax[1, 1].plot(df1["time_stamp"], df1["Machine2.RawMaterial.Property2"], "g")
ax[2, 1].plot(df1["time_stamp"], df1["Machine2.RawMaterial.Property3"], "b")
ax[3, 1].plot(df1["time_stamp"], df1["Machine2.RawMaterial.Property4"], "k")

ax[0, 2].plot(df1["time_stamp"], df1["Machine3.RawMaterial.Property1"], "r")
ax[1, 2].plot(df1["time_stamp"], df1["Machine3.RawMaterial.Property2"], "g")
ax[2, 2].plot(df1["time_stamp"], df1["Machine3.RawMaterial.Property3"], "b")
ax[3, 2].plot(df1["time_stamp"], df1["Machine3.RawMaterial.Property4"], "k")

plt.show()

# %%
df1["Machine1.RawMaterial.Property1"].value_counts()
df1["Machine1.RawMaterial.Property2"].value_counts()
df1["Machine1.RawMaterial.Property3"].value_counts()
df1["Machine1.RawMaterial.Property4"].value_counts()
# Out:
# 11.54    10049
# 12.90     1571
# 12.59     1541
# 12.22      927
# Name: Machine1.RawMaterial.Property1, dtype: int64
# 200    10049
# 215     1571
# 236     1541
# 201      927
# Name: Machine1.RawMaterial.Property2, dtype: int64
# 963.00     5520
# 1027.43    4529
# 980.53     1571
# 601.11     1541
# 1048.06     927
# Name: Machine1.RawMaterial.Property3, dtype: int64
# 247    10049
# 251     1571
# 257     1541
# 252      927
# Name: Machine1.RawMaterial.Property4, dtype: int64

# %%
df1["Machine2.RawMaterial.Property1"].value_counts()
df1["Machine2.RawMaterial.Property2"].value_counts()
df1["Machine2.RawMaterial.Property3"].value_counts()
df1["Machine2.RawMaterial.Property4"].value_counts()
# Out:
# 12.85    11021
# 12.59     3067
# Name: Machine2.RawMaterial.Property1, dtype: int64
# 241    11021
# 236     3067
# Name: Machine2.RawMaterial.Property2, dtype: int64
# 556.70    11021
# 601.11     3067
# Name: Machine2.RawMaterial.Property3, dtype: int64
# 256    11021
# 257     3067
# Name: Machine2.RawMaterial.Property4, dtype: int64

# %%
df1["Machine3.RawMaterial.Property1"].value_counts()
df1["Machine3.RawMaterial.Property2"].value_counts()
df1["Machine3.RawMaterial.Property3"].value_counts()
df1["Machine3.RawMaterial.Property4"].value_counts()
# Out:
# 8.83    7418
# 9.02    3810
# 9.86    2860
# Name: Machine3.RawMaterial.Property1, dtype: int64
# 221    7418
# 186    3810
# 192    2860
# Name: Machine3.RawMaterial.Property2, dtype: int64
# 433.18    7418
# 421.16    3810
# 408.97    2860
# Name: Machine3.RawMaterial.Property3, dtype: int64
# 205    7418
# 200    3810
# 202    2860
# Name: Machine3.RawMaterial.Property4, dtype: int64

# %%
# X, y 분할
X1, y1, X2, y2 = df1.iloc[:, :42], df1.iloc[:, 42:72], df1.iloc[:, 72:86], df1.iloc[:, 86:]

# %% [markdown]
# ## Machine1

# %%
plt.plot(X1["Machine1.RawMaterialFeederParameter.U.Actual"])

# %% [markdown]
# ##### Zone 1,2 Temperature

# %%
X1["Machine1.Zone1Temperature.C.Actual"].max()
X1["Machine1.Zone1Temperature.C.Actual"].min()
X1["Machine1.Zone1Temperature.C.Actual"].median()
plt.plot(X1["Machine1.Zone1Temperature.C.Actual"]) # 삭제?
# Out:
# 72.5
# 71.9
# 72.0

# %%
X1["Machine1.Zone2Temperature.C.Actual"].max()
X1["Machine1.Zone2Temperature.C.Actual"].min() # 삭제?
X1["Machine1.Zone2Temperature.C.Actual"].median()
plt.plot(X1["Machine1.Zone2Temperature.C.Actual"]) # 삭제?
# Out:
# 72.7
# 71.3
# 72.0

# %% [markdown]
# ##### Amperage & RPM

# %%
plt.plot(X1["Machine1.MotorAmperage.U.Actual"])

# %%
plt.plot(X1["Machine1.MotorRPM.C.Actual"])

# %% [markdown]
# ##### Material Pressure & Temperature

# %%
plt.plot(X1["Machine1.MaterialPressure.U.Actual"])

# %%
plt.plot(X1["Machine1.MaterialTemperature.U.Actual"])

# %% [markdown]
# ##### Exit Zone Temperature

# %%
plt.plot(X1["Machine1.ExitZoneTemperature.C.Actual"])

# %% [markdown]
# ## Machine2

# %%
plt.plot(X1["Machine2.RawMaterialFeederParameter.U.Actual"])

# %% [markdown]
# ##### Zone 1,2 Temperature

# %%
X1["Machine2.Zone1Temperature.C.Actual"].max()
X1["Machine2.Zone1Temperature.C.Actual"].min()
X1["Machine2.Zone1Temperature.C.Actual"].median()
plt.plot(X1["Machine2.Zone1Temperature.C.Actual"]) # 삭제?
# Out:
# 69.66
# 68.67
# 68.99

# %%
X1["Machine2.Zone2Temperature.C.Actual"].max()
X1["Machine2.Zone2Temperature.C.Actual"].min()
X1["Machine2.Zone2Temperature.C.Actual"].median()
plt.plot(X1["Machine2.Zone2Temperature.C.Actual"]) # 삭제?
# Out:
# 69.94089066
# 67.78
# 69.09

# %% [markdown]
# ##### Amperage & RPM

# %%
X1["Machine2.MotorAmperage.U.Actual"].max()
X1["Machine2.MotorAmperage.U.Actual"].min()
plt.plot(X1["Machine2.MotorAmperage.U.Actual"]) # 삭제?
# Out:
# 74.38
# 71.56

# %%
X1["Machine2.MotorRPM.C.Actual"].max()
X1["Machine2.MotorRPM.C.Actual"].min()
X1["Machine2.MotorRPM.C.Actual"].median()
plt.plot(X1["Machine2.MotorRPM.C.Actual"])  # 삭제?
# Out:
# 13.97
# 13.82
# 13.9

# %% [markdown]
# ##### Material Pressure & Temperature

# %%
plt.plot(X1["Machine2.MaterialPressure.U.Actual"])

# %%
plt.plot(X1["Machine2.MaterialTemperature.U.Actual"])

# %% [markdown]
# ##### Exit Zone Temperature

# %%
X1["Machine2.ExitZoneTemperature.C.Actual"].max()
X1["Machine2.ExitZoneTemperature.C.Actual"].min()
X1["Machine2.ExitZoneTemperature.C.Actual"].median()
plt.plot(X1["Machine2.ExitZoneTemperature.C.Actual"]) # 삭제?
# Out:
# 60.5
# 59.59871012
# 60.0

# %% [markdown]
# ## Machine3

# %%
plt.plot(X1["Machine3.RawMaterialFeederParameter.U.Actual"])

# %% [markdown]
# ##### Zone 1,2 Temperature

# %%
X1["Machine3.Zone1Temperature.C.Actual"].max()
X1["Machine3.Zone1Temperature.C.Actual"].min()
X1["Machine3.Zone1Temperature.C.Actual"].median()
plt.plot(X1["Machine3.Zone1Temperature.C.Actual"]) # 삭제?
# Out:
# 78.7
# 77.27836438
# 78.0

# %%
X1["Machine3.Zone2Temperature.C.Actual"].max()
X1["Machine3.Zone2Temperature.C.Actual"].min()
X1["Machine3.Zone2Temperature.C.Actual"].median()
plt.plot(X1["Machine3.Zone2Temperature.C.Actual"]) # 삭제?
# Out:
# 78.6
# 77.7
# 78.0

# %% [markdown]
# ##### Amperage & RPM

# %%
plt.plot(X1["Machine3.MotorAmperage.U.Actual"])

# %%
plt.plot(X1["Machine3.MotorRPM.C.Actual"])

# %% [markdown]
# ##### Material Pressure & Temperature

# %%
plt.plot(X1["Machine3.MaterialPressure.U.Actual"])

# %%
plt.plot(X1["Machine3.MaterialTemperature.U.Actual"])

# %% [markdown]
# ##### Exit Zone Temperature

# %%
X1["Machine3.ExitZoneTemperature.C.Actual"].max()
X1["Machine3.ExitZoneTemperature.C.Actual"].min()
X1["Machine3.ExitZoneTemperature.C.Actual"].median()
plt.plot(X1["Machine3.ExitZoneTemperature.C.Actual"]) # 삭제?
# Out:
# 65.2
# 64.8
# 65.0

# %% [markdown]
# ## Combiner

# %%
plt.plot(X1["FirstStage.CombinerOperation.Temperature1.U.Actual"])

# %%
plt.plot(X1["FirstStage.CombinerOperation.Temperature2.U.Actual"])

# %%
X1["FirstStage.CombinerOperation.Temperature3.C.Actual"].max()
X1["FirstStage.CombinerOperation.Temperature3.C.Actual"].min()
X1["FirstStage.CombinerOperation.Temperature3.C.Actual"].median()
plt.plot(X1["FirstStage.CombinerOperation.Temperature3.C.Actual"]) # 삭제?
# Out:
# 80.32163883
# 79.6
# 80.0

# %% [markdown]
# # Stage1 Output

# %%
fig, ax = plt.subplots(5, 3, figsize = (20, 12))

for i in range(15):
    Actual = "Stage1.Output.Measurement" + str(i) + ".U.Actual"
    Setpoint = "Stage1.Output.Measurement" + str(i) + ".U.Setpoint"
    
    row = i // 3
    col = i % 3
    
    ax[row, col].plot(df1[Actual], "r")
    ax[row, col].plot(df1[Setpoint], "b")

plt.show()

# %% [markdown]
# ## Outlier

# %% [markdown]
# ##### 9600번대 튀는값

# %%
plt.plot(X1["Machine1.MaterialPressure.U.Actual"])

# %%
X1["Machine1.MaterialPressure.U.Actual"][8000:11000].idxmax()
# Out:
# 9659

# %%
plt.plot(X1["Machine3.MaterialPressure.U.Actual"])

# %%
X1["Machine3.MaterialPressure.U.Actual"][8000:11000].idxmax()
# Out:
# 9658

# %%
plt.plot(X1["FirstStage.CombinerOperation.Temperature1.U.Actual"])

# %%
X1["FirstStage.CombinerOperation.Temperature1.U.Actual"].idxmin()
# Out:
# 9672

# %%
plt.plot(X1["FirstStage.CombinerOperation.Temperature2.U.Actual"])

# %%
X1["FirstStage.CombinerOperation.Temperature2.U.Actual"][9000:11000].idxmin()
# Out:
# 9658

# %%
X1[["Machine1.MaterialPressure.U.Actual", "Machine3.MaterialPressure.U.Actual", "FirstStage.CombinerOperation.Temperature1.U.Actual", "FirstStage.CombinerOperation.Temperature2.U.Actual"]][9650:9680]
# Out:
#       Machine1.MaterialPressure.U.Actual  Machine3.MaterialPressure.U.Actual  \
# 9650                          374.460000                          247.840000
# 9651                          377.800000                          248.190000
# 9652                          376.910000                          247.480000
# 9653                          370.110000                          248.210000
# 9654                          377.960000                          247.840000
# 9655                          384.160000                          247.440000
# 9656                          407.830000                          251.840000
# 9657                          429.990000                          254.340000
# 9658                          444.430000                          255.890000
# 9659                          461.420000                          255.140000
# 9660                          444.690000                          255.220000
# ...

# %% [markdown]
# 시계열? 딥러닝?

# %% [markdown]
# ##### Setpoint 이상 설정 인덱스

# %%
y1["Stage1.Output.Measurement0.U.Setpoint"].idxmin()
y1["Stage1.Output.Measurement0.U.Setpoint"][4000:4500].idxmin()
# Out:
# 3717
# 4221

# %%
y1["Stage1.Output.Measurement0.U.Setpoint"][3715:3755]
# Out:
# 3715    13.75
# 3716    13.75
# 3717     0.00
# 3718     0.00
# 3719     0.00
# 3720     0.00
# 3721     0.00
# 3722     0.00
# 3723     0.00
# 3724     0.00
# 3725     0.00
# 3726     0.00
# 3727     0.00
# 3728     0.00
# 3729     0.00
# 3730     0.00
# 3731     0.00
# 3732     0.00
# 3733     0.00
# 3734     0.00
# 3735     0.00
# 3736     0.00
# 3737     0.00
# 3738     0.00
# 3739     0.00
# 3740     0.00
# 3741     0.00
# 3742     0.00
# 3743     0.00
# 3744     0.00
# 3745     0.00
# 3746     0.00
# 3747     0.00
# 3748     0.00
# 3749     0.00
# 3750     0.00
# 3751     0.00
# 3752    13.75
# 3753    13.75
# 3754    13.75
# Name: Stage1.Output.Measurement0.U.Setpoint, dtype: float64

# %%
y1["Stage1.Output.Measurement0.U.Setpoint"][4220:4245]
# Out:
# 4220    13.75
# 4221     0.00
# 4222     0.00
# 4223     0.00
# 4224     0.00
# 4225     0.00
# 4226     0.00
# 4227     0.00
# 4228     0.00
# 4229     0.00
# 4230     0.00
# 4231     0.00
# 4232     0.00
# 4233     0.00
# 4234     0.00
# 4235     0.00
# 4236     0.00
# 4237     0.00
# 4238     0.00
# 4239     0.00
# 4240     0.00
# 4241     0.00
# 4242    13.75
# 4243    13.75
# 4244    13.75
# Name: Stage1.Output.Measurement0.U.Setpoint, dtype: float64

# %%
y1["Stage1.Output.Measurement14.U.Setpoint"].idxmin()
y1["Stage1.Output.Measurement14.U.Setpoint"][4000:4500].idxmin()
# Out:
# 3717
# 4221

# %% [markdown]
# # Stage2 Input

# %% [markdown]
# ## Machine4

# %%
plt.plot(X2["Machine4.Temperature1.C.Actual"], "g") # 삭제?

# %%
plt.plot(X2["Machine4.Temperature2.C.Actual"], "g") # 삭제?

# %%
fig, ax = plt.subplots(2, figsize = (8, 8))
ax[0].plot(X2["Machine4.Temperature1.C.Actual"][160:], "g")
ax[1].plot(X2["Machine4.Temperature2.C.Actual"][200:], "g")

# %% [markdown]
#  "Machine4.Temperature4.C.Actual" 와 "Machine4.Pressure.C.Actual" 똑같이 생김

# %%
fig, ax = plt.subplots(2, figsize = (8, 8))
ax[0].plot(X2["Machine4.Temperature4.C.Actual"], "g")
ax[1].plot(X2["Machine4.Pressure.C.Actual"], "g")

# %%
np.corrcoef(X2["Machine4.Pressure.C.Actual"], X2["Machine4.Temperature4.C.Actual"])
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %% [markdown]
# 상관계수 1이므로, 둘 중 하나 삭제 가능

# %%
fig, ax = plt.subplots(2, figsize = (8, 8))
ax[0].plot(X2["Machine4.Temperature3.C.Actual"], "g")
ax[1].plot(X2["Machine4.Temperature5.C.Actual"][200:], "g")

# %% [markdown]
# Temperature 3과 5도 제일 앞부분만 제외하면 굉장히 유사해보임

# %%
np.corrcoef(X2["Machine4.Temperature3.C.Actual"][200:], X2["Machine4.Temperature5.C.Actual"][200:])
# Out:
# array([[1.        , 0.95433834],
#        [0.95433834, 1.        ]])

# %% [markdown]
# 인덱스 200 이후 상관계수 0.95로, 둘 중 하나 삭제 가능할듯

# %%
plt.plot(X2["Machine4.ExitTemperature.U.Actual"], "g")

# %% [markdown]
# ## Machine5

# %%
plt.plot(X2["Machine5.Temperature1.C.Actual"], "g") # 삭제?

# %%
plt.plot(X2["Machine5.Temperature2.C.Actual"], "g") # 삭제?

# %%
plt.plot(X2["Machine5.Temperature3.C.Actual"], "g")

# %%
plt.plot(X2["Machine5.Temperature4.C.Actual"], "g")

# %%
plt.plot(X2["Machine5.Temperature5.C.Actual"], "g") # 삭제?

# %%
plt.plot(X2["Machine5.Temperature6.C.Actual"], "g")

# %%
plt.plot(X2["Machine5.ExitTemperature.U.Actual"], "g")

# %% [markdown]
# ##### 전체적으로 인덱스 0~200에서 크게 튀는 이상치 관찰됨
# ##### 1~200 인덱스 제거하는게 좋을듯

# %% [markdown]
# ## Stage2 Output

# %%
fig, ax = plt.subplots(5, 3, figsize = (20, 12))

for i in range(15):
    Actual = "Stage2.Output.Measurement" + str(i) + ".U.Actual"
    Setpoint = "Stage2.Output.Measurement" + str(i) + ".U.Setpoint"
    
    row = i // 3
    col = i % 3
    
    ax[row, col].plot(y2[Actual], "r")
    ax[row, col].plot(y2[Setpoint], "b")

plt.show()
